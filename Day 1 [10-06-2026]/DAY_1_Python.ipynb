# %%
#List
Languages = [ "Python" ,"R" , "Elixir"]

#length
print(len(Languages))

#append
Languages.append("Java")

#remove
print(Languages)
Languages.remove("Java")
print (Languages)
# Out:
# 3
# ['Python', 'R', 'Elixir', 'Java']
# ['Python', 'R', 'Elixir']

# %%
#Tuple
Languages = ("Python" ,"R" , "Elixir")
print(Languages)

#length
print(len(Languages))

#remove: tuple has no attribute named tuple
#Languages.remove("Java")
#print (Languages)

#indexing
print(Languages[0])
# Out:
# ('Python', 'R', 'Elixir')
# 3
# Python

# %%
#set
Languages = {"Python" ,"R" , "Elixir"}
print(Languages)

#length
print(len(Languages))

#add
Languages.add("Java")
print(Languages)

#remove
Languages.remove("Java")
print(Languages)
# Out:
# {'Python', 'R', 'Elixir'}
# 3
# {'Java', 'Python', 'R', 'Elixir'}
# {'Python', 'R', 'Elixir'}

# %%
#dictionary
marks = {
   "maths": 90 ,
   "phy":60
}
print(marks)
# Out:
# {'maths': 90, 'phy': 60}

# %%
#Function
def languges():
  print("Java")
languges()
# Out:
# Java

# %%
#*args and **kwargs
def myFun(*args,**kwargs):
    print("args: ", args)
    print("kwargs: ", kwargs)
